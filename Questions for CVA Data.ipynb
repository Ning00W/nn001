# %%
import pandas as pd

# %%
import matplotlib
# %matplotlib inline

# %%
path = 'Questions for Data Demo.csv'
Data_Demo = pd.read_csv(path)

# %%
Data_Demo
# Out:
#                          时间戳记 Which is your favorite animal?  \
# 0   2022/11/18 4:57:59 下午 GMT                            Cat
# 1   2022/11/18 4:58:48 下午 GMT                           Bird
# 2   2022/11/18 5:02:18 下午 GMT                            Cat
# 3   2022/11/18 5:24:17 下午 GMT                            Dog
# 4   2022/11/18 8:09:58 下午 GMT                            Dog
# 5  2022/11/18 11:33:36 下午 GMT                            Dog
# 6  2022/11/21 12:43:23 上午 GMT                            Cat
#
#    How many years have you lived in London? How do you travel to Hogarth?  \
# 0                                        23                           Bus
# 1                                        20                    Overground
# 2                                         5                           Bus
# 3                                         0                          Walk
# 4                                         5                   Underground
# ...

# %%
Data_Demo.head()
# Out:
#                         时间戳记 Which is your favorite animal?  \
# 0  2022/11/18 4:57:59 下午 GMT                            Cat
# 1  2022/11/18 4:58:48 下午 GMT                           Bird
# 2  2022/11/18 5:02:18 下午 GMT                            Cat
# 3  2022/11/18 5:24:17 下午 GMT                            Dog
# 4  2022/11/18 8:09:58 下午 GMT                            Dog
#
#    How many years have you lived in London? How do you travel to Hogarth?  \
# 0                                        23                           Bus
# 1                                        20                    Overground
# 2                                         5                           Bus
# 3                                         0                          Walk
# 4                                         5                   Underground
#
#   How do you spend your time during your commute?
# 0                              Listening to Music
# 1                     Responding to texts, emails
# ...

# %%
popular_genre = Data_Demo['Which is your favorite animal?']

# %%
Data_Demo
# Out:
#                          时间戳记 Which is your favorite animal?  \
# 0   2022/11/18 4:57:59 下午 GMT                            Cat
# 1   2022/11/18 4:58:48 下午 GMT                           Bird
# 2   2022/11/18 5:02:18 下午 GMT                            Cat
# 3   2022/11/18 5:24:17 下午 GMT                            Dog
# 4   2022/11/18 8:09:58 下午 GMT                            Dog
# 5  2022/11/18 11:33:36 下午 GMT                            Dog
# 6  2022/11/21 12:43:23 上午 GMT                            Cat
#
#    How many years have you lived in London? How do you travel to Hogarth?  \
# 0                                        23                           Bus
# 1                                        20                    Overground
# 2                                         5                           Bus
# 3                                         0                          Walk
# 4                                         5                   Underground
# ...

# %%
Popular_genre = Data_Demo['How do you travel to Hogarth?']
Data_Demo
# Out:
#                          时间戳记 Which is your favorite animal?  \
# 0   2022/11/18 4:57:59 下午 GMT                            Cat
# 1   2022/11/18 4:58:48 下午 GMT                           Bird
# 2   2022/11/18 5:02:18 下午 GMT                            Cat
# 3   2022/11/18 5:24:17 下午 GMT                            Dog
# 4   2022/11/18 8:09:58 下午 GMT                            Dog
# 5  2022/11/18 11:33:36 下午 GMT                            Dog
# 6  2022/11/21 12:43:23 上午 GMT                            Cat
#
#    How many years have you lived in London? How do you travel to Hogarth?  \
# 0                                        23                           Bus
# 1                                        20                    Overground
# 2                                         5                           Bus
# 3                                         0                          Walk
# 4                                         5                   Underground
# ...

# %%
Popular_genre.unique()
# Out:
# array(['Bus', 'Overground', 'Walk', 'Underground', 'Overground;Walk'],
#       dtype=object)

# %%
from collections import Counter
most_popular = Counter(Popular_genre).most_common(1)
most_popular
# Out:
# [('Bus', 2)]

# %%
Data_Demo.loc[Data_Demo ['How do you spend your time during your commute?'] == 'Listening to Music']
# Out:
#                          时间戳记 Which is your favorite animal?  \
# 0   2022/11/18 4:57:59 下午 GMT                            Cat
# 2   2022/11/18 5:02:18 下午 GMT                            Cat
# 5  2022/11/18 11:33:36 下午 GMT                            Dog
#
#    How many years have you lived in London? How do you travel to Hogarth?  \
# 0                                        23                           Bus
# 2                                         5                           Bus
# 5                                         1               Overground;Walk
#
#   How do you spend your time during your commute?
# 0                              Listening to Music
# 2                              Listening to Music
# 5                              Listening to Music

# %%
popular_rason = Data_Demo ['How do you travel to Hogarth?']

# %%
popular_rason
# Out:
# 0                Bus
# 1         Overground
# 2                Bus
# 3               Walk
# 4        Underground
# 5    Overground;Walk
# 6        Underground
# Name: How do you travel to Hogarth?, dtype: object

# %%
Data_Demo.loc[Data_Demo ['How many years have you lived in London?'] == 0]
# Out:
#                         时间戳记 Which is your favorite animal?  \
# 3  2022/11/18 5:24:17 下午 GMT                            Dog
#
#    How many years have you lived in London? How do you travel to Hogarth?  \
# 3                                         0                          Walk
#
#   How do you spend your time during your commute?
# 3                     Responding to texts, emails
